# %%
'''
Author : Amjad CP
Program : Code A Pookalam

'''

from joy import *

def Out():
    base = circle(r=149, fill='#4b4132', stroke='none')

    c =circle(r=125, fill='#f95639', stroke='none')
    cover = circle(r=17, x=0, y=130, fill='#4b4132', stroke='none') | repeat(24, rotate(15))
    layer1 = c + cover

    c = circle(r=95, fill='#f5e54d', stroke='none')
    cover = circle(r=13, x=0, y=98, fill='#f95639', stroke='none') | repeat(24, rotate(15))
    layer2 = c + cover

    out = base + layer1 + layer2
    return out   

def Vallam():
    #body of vallam
    lin = line(stroke_width=10)
    e = ellipse(h=100, w=60, x=72, y=10, stroke_width=5)
    r1 = rectangle(w=100, h=90, fill='#6c345c', stroke='none', x=39, y=50)
    r2 = rectangle(w=152, h=90, fill='#6c345c', stroke='none', x=32, y=-50)
    body = lin+e+r1+r2

    #panka
    upper = line(x1=-90,y1=20,x2=-60,y2=-10, stroke_width=2)
    lower = line(x1=-60,y1=-10,x2=-50,y2=-20, stroke_width=5)
    panka = (upper+lower) | translate(x=146)
    pankas = panka|scale(1)|repeat(8, translate(x=-20)) 

    #front of vallam
    p1 = point(x=-100,y=0)
    p2 = point(x=-100,y=10)
    p3 = point(x=-130,y=0)
    front = polygon([p1, p2, p3], stroke_width=5, fill='black') | translate(y=-3)

    vallam = body+pankas+front
    vallam1 = vallam | scale(.35) | translate(x=16, y=-30)
    vallam2 = vallam1 | scale(.7) | translate(x=15, y=30)

    vallam_final = vallam1 + vallam2
    
    return vallam_final

def Tree():
    # stump part
    e = ellipse(stroke_width='9') | rotate(90)
    r = rectangle(w=70, h=210,stroke='none', fill='#6c345c') | translate(x=20, y=0)
    stump = e + r
    stump_final = stump | scale(.5)

    #leaf part
    main = line(x1=0,y1=0,x2=125,y2=0, fill='#368809')

    lin1 = line(x1=10,y1=0,x2=25,y2=20, fill='#368809')
    lin2 = line(x1=10, y1=0, x2=25, y2=-20, fill='#368809')
    lin = lin1+lin2

    Lin1 = line(x1=105,y1=0,x2=115,y2=10, fill='#368809')
    Lin2 = line(x1=105,y1=0,x2=115,y2=-10, fill='#368809')
    Lin = Lin1+Lin2

    lin_final = lin | repeat(26, translate(x=5) | scale(.98))
    Lin_final = Lin | repeat(8, translate(x=5) | scale(.98)) 

    leaf = main + lin_final + Lin_final
    leafs1 = leaf | scale(.5) | rotate(-80) | repeat(2, rotate(230) | translate(x=-10))
    leafs2 = leaf | rotate(-20) | repeat(2, rotate(220) | translate(x=-10))  | translate(x=0, y=30)  | scale(.7) 
    leafs_final = leafs2 + leafs1 | scale(.5) | rotate(-30) | translate(x=-10, y=45) 

    tree = stump_final + leafs_final
    tree_final = tree | scale(.5) | rotate(-30) | translate(x=-45, y=-2)

    return tree_final

def Center_circle():
    center_circle = circle(r=84, stroke_width=4, stroke='green', fill='#6c345c')
    sun = circle(r=10, x=10, y=50, fill='#fcae17', stroke='none')
    center = center_circle + sun
    return center

def main():
    show(  
        Out(),
        Center_circle(),
        Tree(),
        Vallam(),
        )
    
main()
# Out:
# SVG:{self.nodes}

# %%
from joy import  *

base = circle(r=149, fill='#4b4132', stroke='none')

c =circle(r=125, fill='#f95639', stroke='none')
cover = circle(r=17, x=0, y=130, fill='#4b4132', stroke='none') | repeat(24, rotate(15))
layer1 = c + cover

c = circle(r=95, fill='#f5e54d', stroke='none')
cover = circle(r=13, x=0, y=110, fill='#f95639', stroke='none') | repeat(24, rotate(15))
layer2 = c + cover

out = base + layer1 + layer2
show(out)
# Out:
# SVG:{self.nodes}

# %%
'''
Author : Amjad CP
Program : Code A Pookalam

'''

from joy import *

def Out():
    base = circle(r=149, fill='#4b4132', stroke='none')

    c =circle(r=125, fill='#f95639', stroke='none')
    cover = circle(r=17, x=0, y=130, fill='#4b4132', stroke='none') | repeat(24, rotate(15))
    layer1 = c + cover

    c = circle(r=95, fill='#f5e54d', stroke='none')
    cover = circle(r=13, x=0, y=110, fill='#f95639', stroke='none') | repeat(24, rotate(15))
    layer2 = c + cover

    out = base + layer1 + layer2
    return out

def Vallam():
    #body of vallam
    lin = line(stroke_width=10)
    e = ellipse(h=100, w=60, x=72, y=10, stroke_width=5)
    r1 = rectangle(w=100, h=90, fill='#6c345c', stroke='none', x=39, y=50)
    r2 = rectangle(w=152, h=90, fill='#6c345c', stroke='none', x=32, y=-50)
    body = lin+e+r1+r2

    #panka
    upper = line(x1=-90,y1=20,x2=-60,y2=-10, stroke_width=2)
    lower = line(x1=-60,y1=-10,x2=-50,y2=-20, stroke_width=5)
    panka = (upper+lower) | translate(x=146)
    pankas = panka|scale(1)|repeat(8, translate(x=-20)) 

    #front of vallam
    p1 = point(x=-100,y=0)
    p2 = point(x=-100,y=10)
    p3 = point(x=-130,y=0)
    front = polygon([p1, p2, p3], stroke_width=5, fill='black') | translate(y=-3)

    vallam = body+pankas+front
    vallam1 = vallam | scale(.35) | translate(x=16, y=-30)
    vallam2 = vallam1 | scale(.7) | translate(x=15, y=30)

    vallam_final = vallam1 + vallam2
    
    return vallam_final

def Tree():
    # stump part
    e = ellipse(stroke_width='9') | rotate(90)
    r = rectangle(w=70, h=210,stroke='none', fill='#6c345c') | translate(x=20, y=0)
    stump = e + r
    stump_final = stump | scale(.5)

    #leaf part
    main = line(x1=0,y1=0,x2=125,y2=0, fill='#368809')

    lin1 = line(x1=10,y1=0,x2=25,y2=20, fill='#368809')
    lin2 = line(x1=10, y1=0, x2=25, y2=-20, fill='#368809')
    lin = lin1+lin2

    Lin1 = line(x1=105,y1=0,x2=115,y2=10, fill='#368809')
    Lin2 = line(x1=105,y1=0,x2=115,y2=-10, fill='#368809')
    Lin = Lin1+Lin2

    lin_final = lin | repeat(26, translate(x=5) | scale(.98))
    Lin_final = Lin | repeat(8, translate(x=5) | scale(.98)) 

    leaf = main + lin_final + Lin_final
    leafs1 = leaf | scale(.5) | rotate(-80) | repeat(2, rotate(230) | translate(x=-10))
    leafs2 = leaf | rotate(-20) | repeat(2, rotate(220) | translate(x=-10))  | translate(x=0, y=30)  | scale(.7) 
    leafs_final = leafs2 + leafs1 | scale(.5) | rotate(-30) | translate(x=-10, y=45) 

    tree = stump_final + leafs_final
    tree_final = tree | scale(.5) | rotate(-30) | translate(x=-45, y=-2)

    return tree_final

def Center_circle():
    center_circle = circle(r=84, stroke_width=4, stroke='green', fill='#6c345c')
    sun = circle(r=10, x=10, y=50, fill='#fcae17', stroke='none')
    center = center_circle + sun
    return center

def main():
    show(  
        Out(),
        Center_circle(),
        Tree(),
        Vallam(),
        )
    
main()
# Out:
# SVG:{self.nodes}
